# %% [markdown]
# ## Problema do Arpirador-de-Pó
#
# Um robô aspirador que se encontra em uma sala quadrada dividida em n posições, tem como objetivo limpar todas as posições da sala.
#
# ### Solução utilizando Algoritmos de Busca Não-Informada (Busca Cega)
#
# Escopo do problema:
#
# * Estados: Posição em que o robo se encontra em um dado momento.
# * Estado Inicial: Qualquer uma das posições.
# * Ações Possíveis: O robo pode andar para quatro posições: esquerda, direita, cima, baixo; e pode limpar a posição.
# * Modelo de Transição: A matriz da sala, mostrando onde já foi limpo.
# * Teste de Objetivo: Todas as posições da sala devem estar limpas.

# %% [markdown]
# ______________________________________________________________________________________________________________________________

# %% [markdown]
# - Será utilizada uma matriz de estados, correspondente ao tamanho da sala. Esta matriz pode ter N linhas e M colunas.
#
# _Inicialmente a matriz de estados é iniciada com todas as posições = 1, equivalente a sala inteira suja. Quando uma posição é limpa, o valor da posição é modificado para 0._

# %%
import numpy as np
from collections import deque

linhas = 3
colunas = 2

matriz_estados = np.zeros((linhas,colunas), dtype=np.int32)

#matriz com o objetivo final, ou seja, todas as posições limpas
matriz_objetivo = matriz_estados.copy()

#matriz de estados inicial, ou seja, todas as posições sujas
matriz_estados[0:linhas, 0:colunas] = 1

custo_caminho = 1

print (matriz_estados)
# Out:
# [[1 1]
#  [1 1]
#  [1 1]]

# %%
# Método utilizado para verificar se a posição inicial definida pelo usuário é valida na matriz de estados.

def estado(linha, coluna):
    erro = True
    
    estado_inicial = [linha,coluna]

    if estado_inicial[0] > linhas or estado_inicial[1] > colunas:
        erro = False
    
    return erro

# %% [markdown]
# #### Ações possíveis
#
# O robo pode realizar 5 ações, que serão armazenadas em um vetor na seguinte sequência:
#
# - limpar
# - esquerda
# - direita
# - cima
# - baixo
#
# Quando uma ação no vetor for igual a 1, esta ação pode ser executada, e não poderá executar quando for 0.

# %%
# Método utilizado para definir as ações possíveis para a posição atual do robo

def acoes_possiveis(estado):
    acoes = [1,1,1,1,1]
        
    if estado[0] == 0:
        acoes[3] = 0
        
    elif estado[0] == (linhas-1):
        acoes[4] = 0
    
    if estado[1] == 0:
        acoes[1] = 0
    
    elif estado[1] == (colunas-1):
        acoes[2] = 0     
    
    return acoes

# %%
# Método utilizado para verificar se todas as posições da matriz foram limpas

def testar_objetivo(no):
    teste_objetivo = False
    
    posicao = estado_inicial.copy()
    
    #copia da matriz original para matriz_transicao -> matriz temporária
    matriz_transicao = matriz_estados.copy()
    
    solucao = avaliar_solucao(no)
    
    for acao in solucao:
        if acao == "Limpar":       
            matriz_transicao[posicao[0]][posicao[1]] = 0
    
        elif acao == "Esquerda":
            posicao[0] -= 1

        elif acao == "Direita":
            posicao[0] += 1

        elif acao == "Cima":
            posicao[1] -= 1

        elif acao == "Baixo":
            posicao[1] += 1
            
    if np.array_equal(matriz_transicao, matriz_objetivo):
        teste_objetivo = True
      
    return teste_objetivo

# %%
#Método que avalia recursivamente todos os nós percorridos

def avaliar_solucao(no_final):
    vetor_solucao = []

    while not no_final.pai == None:
        vetor_solucao.append(no_final.acao)
        no_final = no_final.pai
        
    return vetor_solucao

# %%
class No:

    def __init__(self, estado, pai, acao, custo):
        self.estado = estado
        self.pai = pai
        self.acao = acao
        self.custo = custo
        
    def __repr__(self):
        if self.pai:
            return 'No{\n Estado: %s\n Pai: %s,\n Ação: %s,\n Custo: %s \n}' % (self.estado, self.pai.estado, self.acao, self.custo)
        else:
            return 'No{\n Estado: %s,\n Pai: %s,\n Ação: %s,\n Custo: %s \n}' % (self.estado, 'None', self.acao, self.custo)

# %%
def no_filho(pai, acao):
    
    estado_atual = pai.estado.copy()
    
    if acao[0] == 1:        
        acao_atual = "Limpar"
    
    elif acao[1] == 1:
        estado_atual[0] -= 1
        acao_atual = "Esquerda"
        
    elif acao[2] == 1:
        estado_atual[0] += 1
        acao_atual = "Direita"
        
    elif acao[3] == 1:
        estado_atual[1] -= 1
        acao_atual = "Cima"
    
    elif acao[4] == 1:
        estado_atual[1] += 1
        acao_atual = "Baixo"
        
    print("estado pai: %s acao atual: %s estado_atual: %s" % (pai.estado, acao_atual, estado_atual))
                
    filho = No(estado_atual, pai, acao_atual, pai.custo + 1)
    
    return filho

# %% [markdown]
# ## Algoritmo de Busca em largura

# %%
""" Definição do Nó Raiz """

#entrada da linha e coluna para a posição inicial do robo
linha = 1
coluna = 1


#se a posição inicial existir declara o estado inicial
if estado(linha,coluna):
    
    estado_inicial = [linha-1, coluna-1]
    no_inicial = No(estado_inicial, None, None, 0)
        
else:
    print("Erro")

# %%
""" Busca em largura """

no = no_inicial

borda = deque([no])
explorado = deque()
limite=0

while limite < 500:
    
    limite+=1
    
    if limite == 500:
        print("Atingiu o limite em: ", no)
        
    if testar_objetivo(no):
        solucao = avaliar_solucao(no)
        print (solucao)
        break
        
    elif len(borda) == 0: 
        print('Falha ao explorar os nós')
        break
        
    else:        
        no = borda.popleft()
        explorado.append(no.estado)
        
        acoes = acoes_possiveis(no.estado)
        
        for i, valor in enumerate(acoes):
            acao_atual = [0,0,0,0,0]
            if valor == 1:
                acao_atual[i] = 1
                filho = no_filho(no, acao_atual)  
                if len(list(filter(lambda x: x.estado == filho.estado, borda))) == 0 and not filho.estado in explorado:                    
                    borda.append(filho)
# Out:
# estado pai: [0, 0] acao atual: Limpar estado_atual: [0, 0]
# estado pai: [0, 0] acao atual: Direita estado_atual: [1, 0]
# estado pai: [0, 0] acao atual: Baixo estado_atual: [0, 1]
# estado pai: [1, 0] acao atual: Limpar estado_atual: [1, 0]
# estado pai: [1, 0] acao atual: Direita estado_atual: [2, 0]
# estado pai: [1, 0] acao atual: Cima estado_atual: [1, -1]
# estado pai: [1, 0] acao atual: Baixo estado_atual: [1, 1]
# estado pai: [0, 1] acao atual: Limpar estado_atual: [0, 1]
# estado pai: [0, 1] acao atual: Esquerda estado_atual: [-1, 1]
# estado pai: [0, 1] acao atual: Baixo estado_atual: [0, 2]
# estado pai: [2, 0] acao atual: Limpar estado_atual: [2, 0]
# estado pai: [2, 0] acao atual: Direita estado_atual: [3, 0]
# estado pai: [2, 0] acao atual: Cima estado_atual: [2, -1]
# estado pai: [1, -1] acao atual: Limpar estado_atual: [1, -1]
# estado pai: [1, -1] acao atual: Esquerda estado_atual: [0, -1]
# estado pai: [1, -1] acao atual: Direita estado_atual: [2, -1]
# estado pai: [1, -1] acao atual: Cima estado_atual: [1, -2]
# estado pai: [1, -1] acao atual: Baixo estado_atual: [1, 0]
# estado pai: [1, 1] acao atual: Limpar estado_atual: [1, 1]
# estado pai: [1, 1] acao atual: Esquerda estado_atual: [0, 1]
# estado pai: [1, 1] acao atual: Cima estado_atual: [1, 0]
# estado pai: [1, 1] acao atual: Baixo estado_atual: [1, 2]
# estado pai: [-1, 1] acao atual: Limpar estado_atual: [-1, 1]
# estado pai: [-1, 1] acao atual: Esquerda estado_atual: [-2, 1]
# estado pai: [-1, 1] acao atual: Cima estado_atual: [-1, 0]
# estado pai: [-1, 1] acao atual: Baixo estado_atual: [-1, 2]
# estado pai: [0, 2] acao atual: Limpar estado_atual: [0, 2]
# estado pai: [0, 2] acao atual: Esquerda estado_atual: [-1, 2]
# estado pai: [0, 2] acao atual: Direita estado_atual: [1, 2]
# estado pai: [0, 2] acao atual: Baixo estado_atual: [0, 3]
# estado pai: [3, 0] acao atual: Limpar estado_atual: [3, 0]
# estado pai: [3, 0] acao atual: Direita estado_atual: [4, 0]
# estado pai: [3, 0] acao atual: Cima estado_atual: [3, -1]
# estado pai: [3, 0] acao atual: Baixo estado_atual: [3, 1]
# estado pai: [2, -1] acao atual: Limpar estado_atual: [2, -1]
# estado pai: [2, -1] acao atual: Esquerda estado_atual: [1, -1]
# estado pai: [2, -1] acao atual: Direita estado_atual: [3, -1]
# estado pai: [2, -1] acao atual: Cima estado_atual: [2, -2]
# estado pai: [0, -1] acao atual: Limpar estado_atual: [0, -1]
# estado pai: [0, -1] acao atual: Esquerda estado_atual: [-1, -1]
# estado pai: [0, -1] acao atual: Direita estado_atual: [1, -1]
# estado pai: [0, -1] acao atual: Baixo estado_atual: [0, 0]
# estado pai: [1, -2] acao atual: Limpar estado_atual: [1, -2]
# estado pai: [1, -2] acao atual: Esquerda estado_atual: [0, -2]
# estado pai: [1, -2] acao atual: Direita estado_atual: [2, -2]
# estado pai: [1, -2] acao atual: Cima estado_atual: [1, -3]
# estado pai: [1, -2] acao atual: Baixo estado_atual: [1, -1]
# estado pai: [1, 2] acao atual: Limpar estado_atual: [1, 2]
# estado pai: [1, 2] acao atual: Esquerda estado_atual: [0, 2]
# estado pai: [1, 2] acao atual: Direita estado_atual: [2, 2]
# estado pai: [1, 2] acao atual: Cima estado_atual: [1, 1]
# estado pai: [1, 2] acao atual: Baixo estado_atual: [1, 3]
# estado pai: [-2, 1] acao atual: Limpar estado_atual: [-2, 1]
# estado pai: [-2, 1] acao atual: Esquerda estado_atual: [-3, 1]
# estado pai: [-2, 1] acao atual: Cima estado_atual: [-2, 0]
# estado pai: [-2, 1] acao atual: Baixo estado_atual: [-2, 2]
# estado pai: [-1, 0] acao atual: Limpar estado_atual: [-1, 0]
# estado pai: [-1, 0] acao atual: Direita estado_atual: [0, 0]
# estado pai: [-1, 0] acao atual: Cima estado_atual: [-1, -1]
# estado pai: [-1, 0] acao atual: Baixo estado_atual: [-1, 1]
# estado pai: [-1, 2] acao atual: Limpar estado_atual: [-1, 2]
# estado pai: [-1, 2] acao atual: Esquerda estado_atual: [-2, 2]
# estado pai: [-1, 2] acao atual: Direita estado_atual: [0, 2]
# estado pai: [-1, 2] acao atual: Cima estado_atual: [-1, 1]
# estado pai: [-1, 2] acao atual: Baixo estado_atual: [-1, 3]
# estado pai: [0, 3] acao atual: Limpar estado_atual: [0, 3]
# estado pai: [0, 3] acao atual: Esquerda estado_atual: [-1, 3]
# estado pai: [0, 3] acao atual: Direita estado_atual: [1, 3]
# estado pai: [0, 3] acao atual: Baixo estado_atual: [0, 4]
# estado pai: [4, 0] acao atual: Limpar estado_atual: [4, 0]
# estado pai: [4, 0] acao atual: Direita estado_atual: [5, 0]
# estado pai: [4, 0] acao atual: Cima estado_atual: [4, -1]
# estado pai: [4, 0] acao atual: Baixo estado_atual: [4, 1]
# estado pai: [3, -1] acao atual: Limpar estado_atual: [3, -1]
# estado pai: [3, -1] acao atual: Esquerda estado_atual: [2, -1]
# estado pai: [3, -1] acao atual: Direita estado_atual: [4, -1]
# estado pai: [3, -1] acao atual: Cima estado_atual: [3, -2]
# estado pai: [3, -1] acao atual: Baixo estado_atual: [3, 0]
# estado pai: [3, 1] acao atual: Limpar estado_atual: [3, 1]
# estado pai: [3, 1] acao atual: Esquerda estado_atual: [2, 1]
# estado pai: [3, 1] acao atual: Cima estado_atual: [3, 0]
# estado pai: [3, 1] acao atual: Baixo estado_atual: [3, 2]
# estado pai: [2, -2] acao atual: Limpar estado_atual: [2, -2]
# estado pai: [2, -2] acao atual: Esquerda estado_atual: [1, -2]
# estado pai: [2, -2] acao atual: Direita estado_atual: [3, -2]
# estado pai: [2, -2] acao atual: Cima estado_atual: [2, -3]
# estado pai: [-1, -1] acao atual: Limpar estado_atual: [-1, -1]
# estado pai: [-1, -1] acao atual: Esquerda estado_atual: [-2, -1]
# estado pai: [-1, -1] acao atual: Direita estado_atual: [0, -1]
# estado pai: [-1, -1] acao atual: Cima estado_atual: [-1, -2]
# estado pai: [-1, -1] acao atual: Baixo estado_atual: [-1, 0]
# estado pai: [0, -2] acao atual: Limpar estado_atual: [0, -2]
# estado pai: [0, -2] acao atual: Esquerda estado_atual: [-1, -2]
# estado pai: [0, -2] acao atual: Direita estado_atual: [1, -2]
# estado pai: [0, -2] acao atual: Baixo estado_atual: [0, -1]
# estado pai: [1, -3] acao atual: Limpar estado_atual: [1, -3]
# estado pai: [1, -3] acao atual: Esquerda estado_atual: [0, -3]
# estado pai: [1, -3] acao atual: Direita estado_atual: [2, -3]
# estado pai: [1, -3] acao atual: Cima estado_atual: [1, -4]
# estado pai: [1, -3] acao atual: Baixo estado_atual: [1, -2]
# estado pai: [2, 2] acao atual: Limpar estado_atual: [2, 2]
# estado pai: [2, 2] acao atual: Esquerda estado_atual: [1, 2]
# estado pai: [2, 2] acao atual: Direita estado_atual: [3, 2]
# estado pai: [2, 2] acao atual: Cima estado_atual: [2, 1]
# estado pai: [1, 3] acao atual: Limpar estado_atual: [1, 3]
# estado pai: [1, 3] acao atual: Esquerda estado_atual: [0, 3]
# estado pai: [1, 3] acao atual: Direita estado_atual: [2, 3]
# estado pai: [1, 3] acao atual: Cima estado_atual: [1, 2]
# estado pai: [1, 3] acao atual: Baixo estado_atual: [1, 4]
# estado pai: [-3, 1] acao atual: Limpar estado_atual: [-3, 1]
# estado pai: [-3, 1] acao atual: Esquerda estado_atual: [-4, 1]
# estado pai: [-3, 1] acao atual: Cima estado_atual: [-3, 0]
# estado pai: [-3, 1] acao atual: Baixo estado_atual: [-3, 2]
# estado pai: [-2, 0] acao atual: Limpar estado_atual: [-2, 0]
# estado pai: [-2, 0] acao atual: Direita estado_atual: [-1, 0]
# estado pai: [-2, 0] acao atual: Cima estado_atual: [-2, -1]
# estado pai: [-2, 0] acao atual: Baixo estado_atual: [-2, 1]
# estado pai: [-2, 2] acao atual: Limpar estado_atual: [-2, 2]
# estado pai: [-2, 2] acao atual: Esquerda estado_atual: [-3, 2]
# estado pai: [-2, 2] acao atual: Direita estado_atual: [-1, 2]
# estado pai: [-2, 2] acao atual: Cima estado_atual: [-2, 1]
# estado pai: [-2, 2] acao atual: Baixo estado_atual: [-2, 3]
# estado pai: [-1, 3] acao atual: Limpar estado_atual: [-1, 3]
# estado pai: [-1, 3] acao atual: Esquerda estado_atual: [-2, 3]
# estado pai: [-1, 3] acao atual: Direita estado_atual: [0, 3]
# estado pai: [-1, 3] acao atual: Cima estado_atual: [-1, 2]
# estado pai: [-1, 3] acao atual: Baixo estado_atual: [-1, 4]
# estado pai: [0, 4] acao atual: Limpar estado_atual: [0, 4]
# estado pai: [0, 4] acao atual: Esquerda estado_atual: [-1, 4]
# estado pai: [0, 4] acao atual: Direita estado_atual: [1, 4]
# estado pai: [0, 4] acao atual: Baixo estado_atual: [0, 5]
# estado pai: [5, 0] acao atual: Limpar estado_atual: [5, 0]
# estado pai: [5, 0] acao atual: Direita estado_atual: [6, 0]
# estado pai: [5, 0] acao atual: Cima estado_atual: [5, -1]
# estado pai: [5, 0] acao atual: Baixo estado_atual: [5, 1]
# estado pai: [4, -1] acao atual: Limpar estado_atual: [4, -1]
# estado pai: [4, -1] acao atual: Esquerda estado_atual: [3, -1]
# estado pai: [4, -1] acao atual: Direita estado_atual: [5, -1]
# estado pai: [4, -1] acao atual: Cima estado_atual: [4, -2]
# estado pai: [4, -1] acao atual: Baixo estado_atual: [4, 0]
# estado pai: [4, 1] acao atual: Limpar estado_atual: [4, 1]
# estado pai: [4, 1] acao atual: Esquerda estado_atual: [3, 1]
# estado pai: [4, 1] acao atual: Cima estado_atual: [4, 0]
# estado pai: [4, 1] acao atual: Baixo estado_atual: [4, 2]
# estado pai: [3, -2] acao atual: Limpar estado_atual: [3, -2]
# estado pai: [3, -2] acao atual: Esquerda estado_atual: [2, -2]
# estado pai: [3, -2] acao atual: Direita estado_atual: [4, -2]
# estado pai: [3, -2] acao atual: Cima estado_atual: [3, -3]
# estado pai: [3, -2] acao atual: Baixo estado_atual: [3, -1]
# estado pai: [2, 1] acao atual: Limpar estado_atual: [2, 1]
# estado pai: [2, 1] acao atual: Esquerda estado_atual: [1, 1]
# estado pai: [2, 1] acao atual: Cima estado_atual: [2, 0]
# estado pai: [3, 2] acao atual: Limpar estado_atual: [3, 2]
# estado pai: [3, 2] acao atual: Esquerda estado_atual: [2, 2]
# estado pai: [3, 2] acao atual: Direita estado_atual: [4, 2]
# estado pai: [3, 2] acao atual: Cima estado_atual: [3, 1]
# estado pai: [3, 2] acao atual: Baixo estado_atual: [3, 3]
# estado pai: [2, -3] acao atual: Limpar estado_atual: [2, -3]
# estado pai: [2, -3] acao atual: Esquerda estado_atual: [1, -3]
# estado pai: [2, -3] acao atual: Direita estado_atual: [3, -3]
# estado pai: [2, -3] acao atual: Cima estado_atual: [2, -4]
# estado pai: [-2, -1] acao atual: Limpar estado_atual: [-2, -1]
# estado pai: [-2, -1] acao atual: Esquerda estado_atual: [-3, -1]
# estado pai: [-2, -1] acao atual: Direita estado_atual: [-1, -1]
# estado pai: [-2, -1] acao atual: Cima estado_atual: [-2, -2]
# estado pai: [-2, -1] acao atual: Baixo estado_atual: [-2, 0]
# estado pai: [-1, -2] acao atual: Limpar estado_atual: [-1, -2]
# estado pai: [-1, -2] acao atual: Esquerda estado_atual: [-2, -2]
# estado pai: [-1, -2] acao atual: Direita estado_atual: [0, -2]
# estado pai: [-1, -2] acao atual: Cima estado_atual: [-1, -3]
# estado pai: [-1, -2] acao atual: Baixo estado_atual: [-1, -1]
# estado pai: [0, -3] acao atual: Limpar estado_atual: [0, -3]
# estado pai: [0, -3] acao atual: Esquerda estado_atual: [-1, -3]
# estado pai: [0, -3] acao atual: Direita estado_atual: [1, -3]
# estado pai: [0, -3] acao atual: Baixo estado_atual: [0, -2]
# estado pai: [1, -4] acao atual: Limpar estado_atual: [1, -4]
# estado pai: [1, -4] acao atual: Esquerda estado_atual: [0, -4]
# estado pai: [1, -4] acao atual: Direita estado_atual: [2, -4]
# estado pai: [1, -4] acao atual: Cima estado_atual: [1, -5]
# estado pai: [1, -4] acao atual: Baixo estado_atual: [1, -3]
# estado pai: [2, 3] acao atual: Limpar estado_atual: [2, 3]
# estado pai: [2, 3] acao atual: Esquerda estado_atual: [1, 3]
# estado pai: [2, 3] acao atual: Direita estado_atual: [3, 3]
# estado pai: [2, 3] acao atual: Cima estado_atual: [2, 2]
# estado pai: [1, 4] acao atual: Limpar estado_atual: [1, 4]
# estado pai: [1, 4] acao atual: Esquerda estado_atual: [0, 4]
# estado pai: [1, 4] acao atual: Direita estado_atual: [2, 4]
# estado pai: [1, 4] acao atual: Cima estado_atual: [1, 3]
# estado pai: [1, 4] acao atual: Baixo estado_atual: [1, 5]
# estado pai: [-4, 1] acao atual: Limpar estado_atual: [-4, 1]
# estado pai: [-4, 1] acao atual: Esquerda estado_atual: [-5, 1]
# estado pai: [-4, 1] acao atual: Cima estado_atual: [-4, 0]
# estado pai: [-4, 1] acao atual: Baixo estado_atual: [-4, 2]
# estado pai: [-3, 0] acao atual: Limpar estado_atual: [-3, 0]
# estado pai: [-3, 0] acao atual: Direita estado_atual: [-2, 0]
# estado pai: [-3, 0] acao atual: Cima estado_atual: [-3, -1]
# estado pai: [-3, 0] acao atual: Baixo estado_atual: [-3, 1]
# estado pai: [-3, 2] acao atual: Limpar estado_atual: [-3, 2]
# estado pai: [-3, 2] acao atual: Esquerda estado_atual: [-4, 2]
# estado pai: [-3, 2] acao atual: Direita estado_atual: [-2, 2]
# estado pai: [-3, 2] acao atual: Cima estado_atual: [-3, 1]
# estado pai: [-3, 2] acao atual: Baixo estado_atual: [-3, 3]
# estado pai: [-2, 3] acao atual: Limpar estado_atual: [-2, 3]
# estado pai: [-2, 3] acao atual: Esquerda estado_atual: [-3, 3]
# estado pai: [-2, 3] acao atual: Direita estado_atual: [-1, 3]
# estado pai: [-2, 3] acao atual: Cima estado_atual: [-2, 2]
# estado pai: [-2, 3] acao atual: Baixo estado_atual: [-2, 4]
# estado pai: [-1, 4] acao atual: Limpar estado_atual: [-1, 4]
# estado pai: [-1, 4] acao atual: Esquerda estado_atual: [-2, 4]
# estado pai: [-1, 4] acao atual: Direita estado_atual: [0, 4]
# estado pai: [-1, 4] acao atual: Cima estado_atual: [-1, 3]
# estado pai: [-1, 4] acao atual: Baixo estado_atual: [-1, 5]
# estado pai: [0, 5] acao atual: Limpar estado_atual: [0, 5]
# estado pai: [0, 5] acao atual: Esquerda estado_atual: [-1, 5]
# estado pai: [0, 5] acao atual: Direita estado_atual: [1, 5]
# estado pai: [0, 5] acao atual: Baixo estado_atual: [0, 6]
# estado pai: [6, 0] acao atual: Limpar estado_atual: [6, 0]
# estado pai: [6, 0] acao atual: Direita estado_atual: [7, 0]
# estado pai: [6, 0] acao atual: Cima estado_atual: [6, -1]
# estado pai: [6, 0] acao atual: Baixo estado_atual: [6, 1]
# estado pai: [5, -1] acao atual: Limpar estado_atual: [5, -1]
# estado pai: [5, -1] acao atual: Esquerda estado_atual: [4, -1]
# estado pai: [5, -1] acao atual: Direita estado_atual: [6, -1]
# estado pai: [5, -1] acao atual: Cima estado_atual: [5, -2]
# estado pai: [5, -1] acao atual: Baixo estado_atual: [5, 0]
# estado pai: [5, 1] acao atual: Limpar estado_atual: [5, 1]
# estado pai: [5, 1] acao atual: Esquerda estado_atual: [4, 1]
# estado pai: [5, 1] acao atual: Cima estado_atual: [5, 0]
# estado pai: [5, 1] acao atual: Baixo estado_atual: [5, 2]
# estado pai: [4, -2] acao atual: Limpar estado_atual: [4, -2]
# estado pai: [4, -2] acao atual: Esquerda estado_atual: [3, -2]
# estado pai: [4, -2] acao atual: Direita estado_atual: [5, -2]
# estado pai: [4, -2] acao atual: Cima estado_atual: [4, -3]
# estado pai: [4, -2] acao atual: Baixo estado_atual: [4, -1]
# estado pai: [4, 2] acao atual: Limpar estado_atual: [4, 2]
# estado pai: [4, 2] acao atual: Esquerda estado_atual: [3, 2]
# estado pai: [4, 2] acao atual: Direita estado_atual: [5, 2]
# estado pai: [4, 2] acao atual: Cima estado_atual: [4, 1]
# estado pai: [4, 2] acao atual: Baixo estado_atual: [4, 3]
# estado pai: [3, -3] acao atual: Limpar estado_atual: [3, -3]
# estado pai: [3, -3] acao atual: Esquerda estado_atual: [2, -3]
# estado pai: [3, -3] acao atual: Direita estado_atual: [4, -3]
# estado pai: [3, -3] acao atual: Cima estado_atual: [3, -4]
# estado pai: [3, -3] acao atual: Baixo estado_atual: [3, -2]
# estado pai: [3, 3] acao atual: Limpar estado_atual: [3, 3]
# estado pai: [3, 3] acao atual: Esquerda estado_atual: [2, 3]
# estado pai: [3, 3] acao atual: Direita estado_atual: [4, 3]
# estado pai: [3, 3] acao atual: Cima estado_atual: [3, 2]
# estado pai: [3, 3] acao atual: Baixo estado_atual: [3, 4]
# estado pai: [2, -4] acao atual: Limpar estado_atual: [2, -4]
# estado pai: [2, -4] acao atual: Esquerda estado_atual: [1, -4]
# estado pai: [2, -4] acao atual: Direita estado_atual: [3, -4]
# estado pai: [2, -4] acao atual: Cima estado_atual: [2, -5]
# estado pai: [-3, -1] acao atual: Limpar estado_atual: [-3, -1]
# estado pai: [-3, -1] acao atual: Esquerda estado_atual: [-4, -1]
# estado pai: [-3, -1] acao atual: Direita estado_atual: [-2, -1]
# estado pai: [-3, -1] acao atual: Cima estado_atual: [-3, -2]
# estado pai: [-3, -1] acao atual: Baixo estado_atual: [-3, 0]
# estado pai: [-2, -2] acao atual: Limpar estado_atual: [-2, -2]
# estado pai: [-2, -2] acao atual: Esquerda estado_atual: [-3, -2]
# estado pai: [-2, -2] acao atual: Direita estado_atual: [-1, -2]
# estado pai: [-2, -2] acao atual: Cima estado_atual: [-2, -3]
# estado pai: [-2, -2] acao atual: Baixo estado_atual: [-2, -1]
# estado pai: [-1, -3] acao atual: Limpar estado_atual: [-1, -3]
# estado pai: [-1, -3] acao atual: Esquerda estado_atual: [-2, -3]
# estado pai: [-1, -3] acao atual: Direita estado_atual: [0, -3]
# estado pai: [-1, -3] acao atual: Cima estado_atual: [-1, -4]
# estado pai: [-1, -3] acao atual: Baixo estado_atual: [-1, -2]
# estado pai: [0, -4] acao atual: Limpar estado_atual: [0, -4]
# estado pai: [0, -4] acao atual: Esquerda estado_atual: [-1, -4]
# estado pai: [0, -4] acao atual: Direita estado_atual: [1, -4]
# estado pai: [0, -4] acao atual: Baixo estado_atual: [0, -3]
# estado pai: [1, -5] acao atual: Limpar estado_atual: [1, -5]
# estado pai: [1, -5] acao atual: Esquerda estado_atual: [0, -5]
# estado pai: [1, -5] acao atual: Direita estado_atual: [2, -5]
# estado pai: [1, -5] acao atual: Cima estado_atual: [1, -6]
# estado pai: [1, -5] acao atual: Baixo estado_atual: [1, -4]
# estado pai: [2, 4] acao atual: Limpar estado_atual: [2, 4]
# estado pai: [2, 4] acao atual: Esquerda estado_atual: [1, 4]
# estado pai: [2, 4] acao atual: Direita estado_atual: [3, 4]
# estado pai: [2, 4] acao atual: Cima estado_atual: [2, 3]
# estado pai: [1, 5] acao atual: Limpar estado_atual: [1, 5]
# estado pai: [1, 5] acao atual: Esquerda estado_atual: [0, 5]
# estado pai: [1, 5] acao atual: Direita estado_atual: [2, 5]
# estado pai: [1, 5] acao atual: Cima estado_atual: [1, 4]
# estado pai: [1, 5] acao atual: Baixo estado_atual: [1, 6]
# estado pai: [-5, 1] acao atual: Limpar estado_atual: [-5, 1]
# estado pai: [-5, 1] acao atual: Esquerda estado_atual: [-6, 1]
# estado pai: [-5, 1] acao atual: Cima estado_atual: [-5, 0]
# estado pai: [-5, 1] acao atual: Baixo estado_atual: [-5, 2]
# estado pai: [-4, 0] acao atual: Limpar estado_atual: [-4, 0]
# estado pai: [-4, 0] acao atual: Direita estado_atual: [-3, 0]
# estado pai: [-4, 0] acao atual: Cima estado_atual: [-4, -1]
# estado pai: [-4, 0] acao atual: Baixo estado_atual: [-4, 1]
# estado pai: [-4, 2] acao atual: Limpar estado_atual: [-4, 2]
# estado pai: [-4, 2] acao atual: Esquerda estado_atual: [-5, 2]
# estado pai: [-4, 2] acao atual: Direita estado_atual: [-3, 2]
# estado pai: [-4, 2] acao atual: Cima estado_atual: [-4, 1]
# estado pai: [-4, 2] acao atual: Baixo estado_atual: [-4, 3]
# estado pai: [-3, 3] acao atual: Limpar estado_atual: [-3, 3]
# estado pai: [-3, 3] acao atual: Esquerda estado_atual: [-4, 3]
# estado pai: [-3, 3] acao atual: Direita estado_atual: [-2, 3]
# estado pai: [-3, 3] acao atual: Cima estado_atual: [-3, 2]
# estado pai: [-3, 3] acao atual: Baixo estado_atual: [-3, 4]
# estado pai: [-2, 4] acao atual: Limpar estado_atual: [-2, 4]
# estado pai: [-2, 4] acao atual: Esquerda estado_atual: [-3, 4]
# estado pai: [-2, 4] acao atual: Direita estado_atual: [-1, 4]
# estado pai: [-2, 4] acao atual: Cima estado_atual: [-2, 3]
# estado pai: [-2, 4] acao atual: Baixo estado_atual: [-2, 5]
# estado pai: [-1, 5] acao atual: Limpar estado_atual: [-1, 5]
# estado pai: [-1, 5] acao atual: Esquerda estado_atual: [-2, 5]
# estado pai: [-1, 5] acao atual: Direita estado_atual: [0, 5]
# estado pai: [-1, 5] acao atual: Cima estado_atual: [-1, 4]
# estado pai: [-1, 5] acao atual: Baixo estado_atual: [-1, 6]
# estado pai: [0, 6] acao atual: Limpar estado_atual: [0, 6]
# estado pai: [0, 6] acao atual: Esquerda estado_atual: [-1, 6]
# estado pai: [0, 6] acao atual: Direita estado_atual: [1, 6]
# estado pai: [0, 6] acao atual: Baixo estado_atual: [0, 7]
# estado pai: [7, 0] acao atual: Limpar estado_atual: [7, 0]
# estado pai: [7, 0] acao atual: Direita estado_atual: [8, 0]
# estado pai: [7, 0] acao atual: Cima estado_atual: [7, -1]
# estado pai: [7, 0] acao atual: Baixo estado_atual: [7, 1]
# estado pai: [6, -1] acao atual: Limpar estado_atual: [6, -1]
# estado pai: [6, -1] acao atual: Esquerda estado_atual: [5, -1]
# estado pai: [6, -1] acao atual: Direita estado_atual: [7, -1]
# estado pai: [6, -1] acao atual: Cima estado_atual: [6, -2]
# estado pai: [6, -1] acao atual: Baixo estado_atual: [6, 0]
# estado pai: [6, 1] acao atual: Limpar estado_atual: [6, 1]
# estado pai: [6, 1] acao atual: Esquerda estado_atual: [5, 1]
# estado pai: [6, 1] acao atual: Cima estado_atual: [6, 0]
# estado pai: [6, 1] acao atual: Baixo estado_atual: [6, 2]
# estado pai: [5, -2] acao atual: Limpar estado_atual: [5, -2]
# estado pai: [5, -2] acao atual: Esquerda estado_atual: [4, -2]
# estado pai: [5, -2] acao atual: Direita estado_atual: [6, -2]
# estado pai: [5, -2] acao atual: Cima estado_atual: [5, -3]
# estado pai: [5, -2] acao atual: Baixo estado_atual: [5, -1]
# estado pai: [5, 2] acao atual: Limpar estado_atual: [5, 2]
# estado pai: [5, 2] acao atual: Esquerda estado_atual: [4, 2]
# estado pai: [5, 2] acao atual: Direita estado_atual: [6, 2]
# estado pai: [5, 2] acao atual: Cima estado_atual: [5, 1]
# estado pai: [5, 2] acao atual: Baixo estado_atual: [5, 3]
# estado pai: [4, -3] acao atual: Limpar estado_atual: [4, -3]
# estado pai: [4, -3] acao atual: Esquerda estado_atual: [3, -3]
# estado pai: [4, -3] acao atual: Direita estado_atual: [5, -3]
# estado pai: [4, -3] acao atual: Cima estado_atual: [4, -4]
# estado pai: [4, -3] acao atual: Baixo estado_atual: [4, -2]
# estado pai: [4, 3] acao atual: Limpar estado_atual: [4, 3]
# estado pai: [4, 3] acao atual: Esquerda estado_atual: [3, 3]
# estado pai: [4, 3] acao atual: Direita estado_atual: [5, 3]
# estado pai: [4, 3] acao atual: Cima estado_atual: [4, 2]
# estado pai: [4, 3] acao atual: Baixo estado_atual: [4, 4]
# estado pai: [3, -4] acao atual: Limpar estado_atual: [3, -4]
# estado pai: [3, -4] acao atual: Esquerda estado_atual: [2, -4]
# estado pai: [3, -4] acao atual: Direita estado_atual: [4, -4]
# estado pai: [3, -4] acao atual: Cima estado_atual: [3, -5]
# estado pai: [3, -4] acao atual: Baixo estado_atual: [3, -3]
# estado pai: [3, 4] acao atual: Limpar estado_atual: [3, 4]
# estado pai: [3, 4] acao atual: Esquerda estado_atual: [2, 4]
# estado pai: [3, 4] acao atual: Direita estado_atual: [4, 4]
# estado pai: [3, 4] acao atual: Cima estado_atual: [3, 3]
# estado pai: [3, 4] acao atual: Baixo estado_atual: [3, 5]
# estado pai: [2, -5] acao atual: Limpar estado_atual: [2, -5]
# estado pai: [2, -5] acao atual: Esquerda estado_atual: [1, -5]
# estado pai: [2, -5] acao atual: Direita estado_atual: [3, -5]
# estado pai: [2, -5] acao atual: Cima estado_atual: [2, -6]
# estado pai: [-4, -1] acao atual: Limpar estado_atual: [-4, -1]
# estado pai: [-4, -1] acao atual: Esquerda estado_atual: [-5, -1]
# estado pai: [-4, -1] acao atual: Direita estado_atual: [-3, -1]
# estado pai: [-4, -1] acao atual: Cima estado_atual: [-4, -2]
# estado pai: [-4, -1] acao atual: Baixo estado_atual: [-4, 0]
# estado pai: [-3, -2] acao atual: Limpar estado_atual: [-3, -2]
# estado pai: [-3, -2] acao atual: Esquerda estado_atual: [-4, -2]
# estado pai: [-3, -2] acao atual: Direita estado_atual: [-2, -2]
# estado pai: [-3, -2] acao atual: Cima estado_atual: [-3, -3]
# estado pai: [-3, -2] acao atual: Baixo estado_atual: [-3, -1]
# estado pai: [-2, -3] acao atual: Limpar estado_atual: [-2, -3]
# estado pai: [-2, -3] acao atual: Esquerda estado_atual: [-3, -3]
# estado pai: [-2, -3] acao atual: Direita estado_atual: [-1, -3]
# estado pai: [-2, -3] acao atual: Cima estado_atual: [-2, -4]
# estado pai: [-2, -3] acao atual: Baixo estado_atual: [-2, -2]
# estado pai: [-1, -4] acao atual: Limpar estado_atual: [-1, -4]
# estado pai: [-1, -4] acao atual: Esquerda estado_atual: [-2, -4]
# estado pai: [-1, -4] acao atual: Direita estado_atual: [0, -4]
# estado pai: [-1, -4] acao atual: Cima estado_atual: [-1, -5]
# estado pai: [-1, -4] acao atual: Baixo estado_atual: [-1, -3]
# estado pai: [0, -5] acao atual: Limpar estado_atual: [0, -5]
# estado pai: [0, -5] acao atual: Esquerda estado_atual: [-1, -5]
# estado pai: [0, -5] acao atual: Direita estado_atual: [1, -5]
# estado pai: [0, -5] acao atual: Baixo estado_atual: [0, -4]
# estado pai: [1, -6] acao atual: Limpar estado_atual: [1, -6]
# estado pai: [1, -6] acao atual: Esquerda estado_atual: [0, -6]
# estado pai: [1, -6] acao atual: Direita estado_atual: [2, -6]
# estado pai: [1, -6] acao atual: Cima estado_atual: [1, -7]
# estado pai: [1, -6] acao atual: Baixo estado_atual: [1, -5]
# estado pai: [2, 5] acao atual: Limpar estado_atual: [2, 5]
# estado pai: [2, 5] acao atual: Esquerda estado_atual: [1, 5]
# estado pai: [2, 5] acao atual: Direita estado_atual: [3, 5]
# estado pai: [2, 5] acao atual: Cima estado_atual: [2, 4]
# estado pai: [1, 6] acao atual: Limpar estado_atual: [1, 6]
# estado pai: [1, 6] acao atual: Esquerda estado_atual: [0, 6]
# estado pai: [1, 6] acao atual: Direita estado_atual: [2, 6]
# estado pai: [1, 6] acao atual: Cima estado_atual: [1, 5]
# estado pai: [1, 6] acao atual: Baixo estado_atual: [1, 7]
# estado pai: [-6, 1] acao atual: Limpar estado_atual: [-6, 1]
# estado pai: [-6, 1] acao atual: Esquerda estado_atual: [-7, 1]
# estado pai: [-6, 1] acao atual: Cima estado_atual: [-6, 0]
# estado pai: [-6, 1] acao atual: Baixo estado_atual: [-6, 2]
# estado pai: [-5, 0] acao atual: Limpar estado_atual: [-5, 0]
# estado pai: [-5, 0] acao atual: Direita estado_atual: [-4, 0]
# estado pai: [-5, 0] acao atual: Cima estado_atual: [-5, -1]
# estado pai: [-5, 0] acao atual: Baixo estado_atual: [-5, 1]
# estado pai: [-5, 2] acao atual: Limpar estado_atual: [-5, 2]
# estado pai: [-5, 2] acao atual: Esquerda estado_atual: [-6, 2]
# estado pai: [-5, 2] acao atual: Direita estado_atual: [-4, 2]
# estado pai: [-5, 2] acao atual: Cima estado_atual: [-5, 1]
# estado pai: [-5, 2] acao atual: Baixo estado_atual: [-5, 3]
# estado pai: [-4, 3] acao atual: Limpar estado_atual: [-4, 3]
# estado pai: [-4, 3] acao atual: Esquerda estado_atual: [-5, 3]
# estado pai: [-4, 3] acao atual: Direita estado_atual: [-3, 3]
# estado pai: [-4, 3] acao atual: Cima estado_atual: [-4, 2]
# estado pai: [-4, 3] acao atual: Baixo estado_atual: [-4, 4]
# estado pai: [-3, 4] acao atual: Limpar estado_atual: [-3, 4]
# estado pai: [-3, 4] acao atual: Esquerda estado_atual: [-4, 4]
# estado pai: [-3, 4] acao atual: Direita estado_atual: [-2, 4]
# estado pai: [-3, 4] acao atual: Cima estado_atual: [-3, 3]
# estado pai: [-3, 4] acao atual: Baixo estado_atual: [-3, 5]
# estado pai: [-2, 5] acao atual: Limpar estado_atual: [-2, 5]
# estado pai: [-2, 5] acao atual: Esquerda estado_atual: [-3, 5]
# estado pai: [-2, 5] acao atual: Direita estado_atual: [-1, 5]
# estado pai: [-2, 5] acao atual: Cima estado_atual: [-2, 4]
# estado pai: [-2, 5] acao atual: Baixo estado_atual: [-2, 6]
# estado pai: [-1, 6] acao atual: Limpar estado_atual: [-1, 6]
# estado pai: [-1, 6] acao atual: Esquerda estado_atual: [-2, 6]
# estado pai: [-1, 6] acao atual: Direita estado_atual: [0, 6]
# estado pai: [-1, 6] acao atual: Cima estado_atual: [-1, 5]
# estado pai: [-1, 6] acao atual: Baixo estado_atual: [-1, 7]
# estado pai: [0, 7] acao atual: Limpar estado_atual: [0, 7]
# estado pai: [0, 7] acao atual: Esquerda estado_atual: [-1, 7]
# estado pai: [0, 7] acao atual: Direita estado_atual: [1, 7]
# estado pai: [0, 7] acao atual: Baixo estado_atual: [0, 8]
# estado pai: [8, 0] acao atual: Limpar estado_atual: [8, 0]
# estado pai: [8, 0] acao atual: Direita estado_atual: [9, 0]
# estado pai: [8, 0] acao atual: Cima estado_atual: [8, -1]
# estado pai: [8, 0] acao atual: Baixo estado_atual: [8, 1]
# estado pai: [7, -1] acao atual: Limpar estado_atual: [7, -1]
# estado pai: [7, -1] acao atual: Esquerda estado_atual: [6, -1]
# estado pai: [7, -1] acao atual: Direita estado_atual: [8, -1]
# estado pai: [7, -1] acao atual: Cima estado_atual: [7, -2]
# estado pai: [7, -1] acao atual: Baixo estado_atual: [7, 0]
# estado pai: [7, 1] acao atual: Limpar estado_atual: [7, 1]
# estado pai: [7, 1] acao atual: Esquerda estado_atual: [6, 1]
# estado pai: [7, 1] acao atual: Cima estado_atual: [7, 0]
# estado pai: [7, 1] acao atual: Baixo estado_atual: [7, 2]
# estado pai: [6, -2] acao atual: Limpar estado_atual: [6, -2]
# estado pai: [6, -2] acao atual: Esquerda estado_atual: [5, -2]
# estado pai: [6, -2] acao atual: Direita estado_atual: [7, -2]
# estado pai: [6, -2] acao atual: Cima estado_atual: [6, -3]
# estado pai: [6, -2] acao atual: Baixo estado_atual: [6, -1]
# estado pai: [6, 2] acao atual: Limpar estado_atual: [6, 2]
# estado pai: [6, 2] acao atual: Esquerda estado_atual: [5, 2]
# estado pai: [6, 2] acao atual: Direita estado_atual: [7, 2]
# estado pai: [6, 2] acao atual: Cima estado_atual: [6, 1]
# estado pai: [6, 2] acao atual: Baixo estado_atual: [6, 3]
# estado pai: [5, -3] acao atual: Limpar estado_atual: [5, -3]
# estado pai: [5, -3] acao atual: Esquerda estado_atual: [4, -3]
# estado pai: [5, -3] acao atual: Direita estado_atual: [6, -3]
# estado pai: [5, -3] acao atual: Cima estado_atual: [5, -4]
# estado pai: [5, -3] acao atual: Baixo estado_atual: [5, -2]
# estado pai: [5, 3] acao atual: Limpar estado_atual: [5, 3]
# estado pai: [5, 3] acao atual: Esquerda estado_atual: [4, 3]
# estado pai: [5, 3] acao atual: Direita estado_atual: [6, 3]
# estado pai: [5, 3] acao atual: Cima estado_atual: [5, 2]
# estado pai: [5, 3] acao atual: Baixo estado_atual: [5, 4]
# estado pai: [4, -4] acao atual: Limpar estado_atual: [4, -4]
# estado pai: [4, -4] acao atual: Esquerda estado_atual: [3, -4]
# estado pai: [4, -4] acao atual: Direita estado_atual: [5, -4]
# estado pai: [4, -4] acao atual: Cima estado_atual: [4, -5]
# estado pai: [4, -4] acao atual: Baixo estado_atual: [4, -3]
# estado pai: [4, 4] acao atual: Limpar estado_atual: [4, 4]
# estado pai: [4, 4] acao atual: Esquerda estado_atual: [3, 4]
# estado pai: [4, 4] acao atual: Direita estado_atual: [5, 4]
# estado pai: [4, 4] acao atual: Cima estado_atual: [4, 3]
# estado pai: [4, 4] acao atual: Baixo estado_atual: [4, 5]
# estado pai: [3, -5] acao atual: Limpar estado_atual: [3, -5]
# estado pai: [3, -5] acao atual: Esquerda estado_atual: [2, -5]
# estado pai: [3, -5] acao atual: Direita estado_atual: [4, -5]
# estado pai: [3, -5] acao atual: Cima estado_atual: [3, -6]
# estado pai: [3, -5] acao atual: Baixo estado_atual: [3, -4]
# estado pai: [3, 5] acao atual: Limpar estado_atual: [3, 5]
# estado pai: [3, 5] acao atual: Esquerda estado_atual: [2, 5]
# estado pai: [3, 5] acao atual: Direita estado_atual: [4, 5]
# estado pai: [3, 5] acao atual: Cima estado_atual: [3, 4]
# estado pai: [3, 5] acao atual: Baixo estado_atual: [3, 6]
# estado pai: [2, -6] acao atual: Limpar estado_atual: [2, -6]
# estado pai: [2, -6] acao atual: Esquerda estado_atual: [1, -6]
# estado pai: [2, -6] acao atual: Direita estado_atual: [3, -6]
# estado pai: [2, -6] acao atual: Cima estado_atual: [2, -7]
# estado pai: [-5, -1] acao atual: Limpar estado_atual: [-5, -1]
# estado pai: [-5, -1] acao atual: Esquerda estado_atual: [-6, -1]
# estado pai: [-5, -1] acao atual: Direita estado_atual: [-4, -1]
# estado pai: [-5, -1] acao atual: Cima estado_atual: [-5, -2]
# estado pai: [-5, -1] acao atual: Baixo estado_atual: [-5, 0]
# estado pai: [-4, -2] acao atual: Limpar estado_atual: [-4, -2]
# estado pai: [-4, -2] acao atual: Esquerda estado_atual: [-5, -2]
# estado pai: [-4, -2] acao atual: Direita estado_atual: [-3, -2]
# estado pai: [-4, -2] acao atual: Cima estado_atual: [-4, -3]
# estado pai: [-4, -2] acao atual: Baixo estado_atual: [-4, -1]
# estado pai: [-3, -3] acao atual: Limpar estado_atual: [-3, -3]
# estado pai: [-3, -3] acao atual: Esquerda estado_atual: [-4, -3]
# estado pai: [-3, -3] acao atual: Direita estado_atual: [-2, -3]
# estado pai: [-3, -3] acao atual: Cima estado_atual: [-3, -4]
# estado pai: [-3, -3] acao atual: Baixo estado_atual: [-3, -2]
# estado pai: [-2, -4] acao atual: Limpar estado_atual: [-2, -4]
# estado pai: [-2, -4] acao atual: Esquerda estado_atual: [-3, -4]
# estado pai: [-2, -4] acao atual: Direita estado_atual: [-1, -4]
# estado pai: [-2, -4] acao atual: Cima estado_atual: [-2, -5]
# estado pai: [-2, -4] acao atual: Baixo estado_atual: [-2, -3]
# estado pai: [-1, -5] acao atual: Limpar estado_atual: [-1, -5]
# estado pai: [-1, -5] acao atual: Esquerda estado_atual: [-2, -5]
# estado pai: [-1, -5] acao atual: Direita estado_atual: [0, -5]
# estado pai: [-1, -5] acao atual: Cima estado_atual: [-1, -6]
# estado pai: [-1, -5] acao atual: Baixo estado_atual: [-1, -4]
# estado pai: [0, -6] acao atual: Limpar estado_atual: [0, -6]
# estado pai: [0, -6] acao atual: Esquerda estado_atual: [-1, -6]
# estado pai: [0, -6] acao atual: Direita estado_atual: [1, -6]
# estado pai: [0, -6] acao atual: Baixo estado_atual: [0, -5]
# estado pai: [1, -7] acao atual: Limpar estado_atual: [1, -7]
# estado pai: [1, -7] acao atual: Esquerda estado_atual: [0, -7]
# estado pai: [1, -7] acao atual: Direita estado_atual: [2, -7]
# estado pai: [1, -7] acao atual: Cima estado_atual: [1, -8]
# estado pai: [1, -7] acao atual: Baixo estado_atual: [1, -6]
# estado pai: [2, 6] acao atual: Limpar estado_atual: [2, 6]
# estado pai: [2, 6] acao atual: Esquerda estado_atual: [1, 6]
# estado pai: [2, 6] acao atual: Direita estado_atual: [3, 6]
# estado pai: [2, 6] acao atual: Cima estado_atual: [2, 5]
# estado pai: [1, 7] acao atual: Limpar estado_atual: [1, 7]
# estado pai: [1, 7] acao atual: Esquerda estado_atual: [0, 7]
# estado pai: [1, 7] acao atual: Direita estado_atual: [2, 7]
# estado pai: [1, 7] acao atual: Cima estado_atual: [1, 6]
# estado pai: [1, 7] acao atual: Baixo estado_atual: [1, 8]
# estado pai: [-7, 1] acao atual: Limpar estado_atual: [-7, 1]
# estado pai: [-7, 1] acao atual: Esquerda estado_atual: [-8, 1]
# estado pai: [-7, 1] acao atual: Cima estado_atual: [-7, 0]
# estado pai: [-7, 1] acao atual: Baixo estado_atual: [-7, 2]
# estado pai: [-6, 0] acao atual: Limpar estado_atual: [-6, 0]
# estado pai: [-6, 0] acao atual: Direita estado_atual: [-5, 0]
# estado pai: [-6, 0] acao atual: Cima estado_atual: [-6, -1]
# estado pai: [-6, 0] acao atual: Baixo estado_atual: [-6, 1]
# estado pai: [-6, 2] acao atual: Limpar estado_atual: [-6, 2]
# estado pai: [-6, 2] acao atual: Esquerda estado_atual: [-7, 2]
# estado pai: [-6, 2] acao atual: Direita estado_atual: [-5, 2]
# estado pai: [-6, 2] acao atual: Cima estado_atual: [-6, 1]
# estado pai: [-6, 2] acao atual: Baixo estado_atual: [-6, 3]
# estado pai: [-5, 3] acao atual: Limpar estado_atual: [-5, 3]
# estado pai: [-5, 3] acao atual: Esquerda estado_atual: [-6, 3]
# estado pai: [-5, 3] acao atual: Direita estado_atual: [-4, 3]
# estado pai: [-5, 3] acao atual: Cima estado_atual: [-5, 2]
# estado pai: [-5, 3] acao atual: Baixo estado_atual: [-5, 4]
# estado pai: [-4, 4] acao atual: Limpar estado_atual: [-4, 4]
# estado pai: [-4, 4] acao atual: Esquerda estado_atual: [-5, 4]
# estado pai: [-4, 4] acao atual: Direita estado_atual: [-3, 4]
# estado pai: [-4, 4] acao atual: Cima estado_atual: [-4, 3]
# estado pai: [-4, 4] acao atual: Baixo estado_atual: [-4, 5]
# estado pai: [-3, 5] acao atual: Limpar estado_atual: [-3, 5]
# estado pai: [-3, 5] acao atual: Esquerda estado_atual: [-4, 5]
# estado pai: [-3, 5] acao atual: Direita estado_atual: [-2, 5]
# estado pai: [-3, 5] acao atual: Cima estado_atual: [-3, 4]
# estado pai: [-3, 5] acao atual: Baixo estado_atual: [-3, 6]
# estado pai: [-2, 6] acao atual: Limpar estado_atual: [-2, 6]
# estado pai: [-2, 6] acao atual: Esquerda estado_atual: [-3, 6]
# estado pai: [-2, 6] acao atual: Direita estado_atual: [-1, 6]
# estado pai: [-2, 6] acao atual: Cima estado_atual: [-2, 5]
# estado pai: [-2, 6] acao atual: Baixo estado_atual: [-2, 7]
# estado pai: [-1, 7] acao atual: Limpar estado_atual: [-1, 7]
# estado pai: [-1, 7] acao atual: Esquerda estado_atual: [-2, 7]
# estado pai: [-1, 7] acao atual: Direita estado_atual: [0, 7]
# estado pai: [-1, 7] acao atual: Cima estado_atual: [-1, 6]
# estado pai: [-1, 7] acao atual: Baixo estado_atual: [-1, 8]
# estado pai: [0, 8] acao atual: Limpar estado_atual: [0, 8]
# estado pai: [0, 8] acao atual: Esquerda estado_atual: [-1, 8]
# estado pai: [0, 8] acao atual: Direita estado_atual: [1, 8]
# estado pai: [0, 8] acao atual: Baixo estado_atual: [0, 9]
# estado pai: [9, 0] acao atual: Limpar estado_atual: [9, 0]
# estado pai: [9, 0] acao atual: Direita estado_atual: [10, 0]
# estado pai: [9, 0] acao atual: Cima estado_atual: [9, -1]
# estado pai: [9, 0] acao atual: Baixo estado_atual: [9, 1]
# estado pai: [8, -1] acao atual: Limpar estado_atual: [8, -1]
# estado pai: [8, -1] acao atual: Esquerda estado_atual: [7, -1]
# estado pai: [8, -1] acao atual: Direita estado_atual: [9, -1]
# estado pai: [8, -1] acao atual: Cima estado_atual: [8, -2]
# estado pai: [8, -1] acao atual: Baixo estado_atual: [8, 0]
# estado pai: [8, 1] acao atual: Limpar estado_atual: [8, 1]
# estado pai: [8, 1] acao atual: Esquerda estado_atual: [7, 1]
# estado pai: [8, 1] acao atual: Cima estado_atual: [8, 0]
# estado pai: [8, 1] acao atual: Baixo estado_atual: [8, 2]
# estado pai: [7, -2] acao atual: Limpar estado_atual: [7, -2]
# estado pai: [7, -2] acao atual: Esquerda estado_atual: [6, -2]
# estado pai: [7, -2] acao atual: Direita estado_atual: [8, -2]
# estado pai: [7, -2] acao atual: Cima estado_atual: [7, -3]
# estado pai: [7, -2] acao atual: Baixo estado_atual: [7, -1]
# estado pai: [7, 2] acao atual: Limpar estado_atual: [7, 2]
# estado pai: [7, 2] acao atual: Esquerda estado_atual: [6, 2]
# estado pai: [7, 2] acao atual: Direita estado_atual: [8, 2]
# estado pai: [7, 2] acao atual: Cima estado_atual: [7, 1]
# estado pai: [7, 2] acao atual: Baixo estado_atual: [7, 3]
# estado pai: [6, -3] acao atual: Limpar estado_atual: [6, -3]
# estado pai: [6, -3] acao atual: Esquerda estado_atual: [5, -3]
# estado pai: [6, -3] acao atual: Direita estado_atual: [7, -3]
# estado pai: [6, -3] acao atual: Cima estado_atual: [6, -4]
# estado pai: [6, -3] acao atual: Baixo estado_atual: [6, -2]
# estado pai: [6, 3] acao atual: Limpar estado_atual: [6, 3]
# estado pai: [6, 3] acao atual: Esquerda estado_atual: [5, 3]
# estado pai: [6, 3] acao atual: Direita estado_atual: [7, 3]
# estado pai: [6, 3] acao atual: Cima estado_atual: [6, 2]
# estado pai: [6, 3] acao atual: Baixo estado_atual: [6, 4]
# estado pai: [5, -4] acao atual: Limpar estado_atual: [5, -4]
# estado pai: [5, -4] acao atual: Esquerda estado_atual: [4, -4]
# estado pai: [5, -4] acao atual: Direita estado_atual: [6, -4]
# estado pai: [5, -4] acao atual: Cima estado_atual: [5, -5]
# estado pai: [5, -4] acao atual: Baixo estado_atual: [5, -3]
# estado pai: [5, 4] acao atual: Limpar estado_atual: [5, 4]
# estado pai: [5, 4] acao atual: Esquerda estado_atual: [4, 4]
# estado pai: [5, 4] acao atual: Direita estado_atual: [6, 4]
# estado pai: [5, 4] acao atual: Cima estado_atual: [5, 3]
# estado pai: [5, 4] acao atual: Baixo estado_atual: [5, 5]
# estado pai: [4, -5] acao atual: Limpar estado_atual: [4, -5]
# estado pai: [4, -5] acao atual: Esquerda estado_atual: [3, -5]
# estado pai: [4, -5] acao atual: Direita estado_atual: [5, -5]
# estado pai: [4, -5] acao atual: Cima estado_atual: [4, -6]
# estado pai: [4, -5] acao atual: Baixo estado_atual: [4, -4]
# estado pai: [4, 5] acao atual: Limpar estado_atual: [4, 5]
# estado pai: [4, 5] acao atual: Esquerda estado_atual: [3, 5]
# estado pai: [4, 5] acao atual: Direita estado_atual: [5, 5]
# estado pai: [4, 5] acao atual: Cima estado_atual: [4, 4]
# estado pai: [4, 5] acao atual: Baixo estado_atual: [4, 6]
# estado pai: [3, -6] acao atual: Limpar estado_atual: [3, -6]
# estado pai: [3, -6] acao atual: Esquerda estado_atual: [2, -6]
# estado pai: [3, -6] acao atual: Direita estado_atual: [4, -6]
# estado pai: [3, -6] acao atual: Cima estado_atual: [3, -7]
# estado pai: [3, -6] acao atual: Baixo estado_atual: [3, -5]
# estado pai: [3, 6] acao atual: Limpar estado_atual: [3, 6]
# estado pai: [3, 6] acao atual: Esquerda estado_atual: [2, 6]
# estado pai: [3, 6] acao atual: Direita estado_atual: [4, 6]
# estado pai: [3, 6] acao atual: Cima estado_atual: [3, 5]
# estado pai: [3, 6] acao atual: Baixo estado_atual: [3, 7]
# estado pai: [2, -7] acao atual: Limpar estado_atual: [2, -7]
# estado pai: [2, -7] acao atual: Esquerda estado_atual: [1, -7]
# estado pai: [2, -7] acao atual: Direita estado_atual: [3, -7]
# estado pai: [2, -7] acao atual: Cima estado_atual: [2, -8]
# estado pai: [-6, -1] acao atual: Limpar estado_atual: [-6, -1]
# estado pai: [-6, -1] acao atual: Esquerda estado_atual: [-7, -1]
# estado pai: [-6, -1] acao atual: Direita estado_atual: [-5, -1]
# estado pai: [-6, -1] acao atual: Cima estado_atual: [-6, -2]
# estado pai: [-6, -1] acao atual: Baixo estado_atual: [-6, 0]
# estado pai: [-5, -2] acao atual: Limpar estado_atual: [-5, -2]
# estado pai: [-5, -2] acao atual: Esquerda estado_atual: [-6, -2]
# estado pai: [-5, -2] acao atual: Direita estado_atual: [-4, -2]
# estado pai: [-5, -2] acao atual: Cima estado_atual: [-5, -3]
# estado pai: [-5, -2] acao atual: Baixo estado_atual: [-5, -1]
# estado pai: [-4, -3] acao atual: Limpar estado_atual: [-4, -3]
# estado pai: [-4, -3] acao atual: Esquerda estado_atual: [-5, -3]
# estado pai: [-4, -3] acao atual: Direita estado_atual: [-3, -3]
# estado pai: [-4, -3] acao atual: Cima estado_atual: [-4, -4]
# estado pai: [-4, -3] acao atual: Baixo estado_atual: [-4, -2]
# estado pai: [-3, -4] acao atual: Limpar estado_atual: [-3, -4]
# estado pai: [-3, -4] acao atual: Esquerda estado_atual: [-4, -4]
# estado pai: [-3, -4] acao atual: Direita estado_atual: [-2, -4]
# estado pai: [-3, -4] acao atual: Cima estado_atual: [-3, -5]
# estado pai: [-3, -4] acao atual: Baixo estado_atual: [-3, -3]
# estado pai: [-2, -5] acao atual: Limpar estado_atual: [-2, -5]
# estado pai: [-2, -5] acao atual: Esquerda estado_atual: [-3, -5]
# estado pai: [-2, -5] acao atual: Direita estado_atual: [-1, -5]
# estado pai: [-2, -5] acao atual: Cima estado_atual: [-2, -6]
# estado pai: [-2, -5] acao atual: Baixo estado_atual: [-2, -4]
# estado pai: [-1, -6] acao atual: Limpar estado_atual: [-1, -6]
# estado pai: [-1, -6] acao atual: Esquerda estado_atual: [-2, -6]
# estado pai: [-1, -6] acao atual: Direita estado_atual: [0, -6]
# estado pai: [-1, -6] acao atual: Cima estado_atual: [-1, -7]
# estado pai: [-1, -6] acao atual: Baixo estado_atual: [-1, -5]
# estado pai: [0, -7] acao atual: Limpar estado_atual: [0, -7]
# estado pai: [0, -7] acao atual: Esquerda estado_atual: [-1, -7]
# estado pai: [0, -7] acao atual: Direita estado_atual: [1, -7]
# estado pai: [0, -7] acao atual: Baixo estado_atual: [0, -6]
# estado pai: [1, -8] acao atual: Limpar estado_atual: [1, -8]
# estado pai: [1, -8] acao atual: Esquerda estado_atual: [0, -8]
# estado pai: [1, -8] acao atual: Direita estado_atual: [2, -8]
# estado pai: [1, -8] acao atual: Cima estado_atual: [1, -9]
# estado pai: [1, -8] acao atual: Baixo estado_atual: [1, -7]
# estado pai: [2, 7] acao atual: Limpar estado_atual: [2, 7]
# estado pai: [2, 7] acao atual: Esquerda estado_atual: [1, 7]
# estado pai: [2, 7] acao atual: Direita estado_atual: [3, 7]
# estado pai: [2, 7] acao atual: Cima estado_atual: [2, 6]
# estado pai: [1, 8] acao atual: Limpar estado_atual: [1, 8]
# estado pai: [1, 8] acao atual: Esquerda estado_atual: [0, 8]
# estado pai: [1, 8] acao atual: Direita estado_atual: [2, 8]
# estado pai: [1, 8] acao atual: Cima estado_atual: [1, 7]
# estado pai: [1, 8] acao atual: Baixo estado_atual: [1, 9]
# estado pai: [-8, 1] acao atual: Limpar estado_atual: [-8, 1]
# estado pai: [-8, 1] acao atual: Esquerda estado_atual: [-9, 1]
# estado pai: [-8, 1] acao atual: Cima estado_atual: [-8, 0]
# estado pai: [-8, 1] acao atual: Baixo estado_atual: [-8, 2]
# estado pai: [-7, 0] acao atual: Limpar estado_atual: [-7, 0]
# estado pai: [-7, 0] acao atual: Direita estado_atual: [-6, 0]
# estado pai: [-7, 0] acao atual: Cima estado_atual: [-7, -1]
# estado pai: [-7, 0] acao atual: Baixo estado_atual: [-7, 1]
# estado pai: [-7, 2] acao atual: Limpar estado_atual: [-7, 2]
# estado pai: [-7, 2] acao atual: Esquerda estado_atual: [-8, 2]
# estado pai: [-7, 2] acao atual: Direita estado_atual: [-6, 2]
# estado pai: [-7, 2] acao atual: Cima estado_atual: [-7, 1]
# estado pai: [-7, 2] acao atual: Baixo estado_atual: [-7, 3]
# estado pai: [-6, 3] acao atual: Limpar estado_atual: [-6, 3]
# estado pai: [-6, 3] acao atual: Esquerda estado_atual: [-7, 3]
# estado pai: [-6, 3] acao atual: Direita estado_atual: [-5, 3]
# estado pai: [-6, 3] acao atual: Cima estado_atual: [-6, 2]
# estado pai: [-6, 3] acao atual: Baixo estado_atual: [-6, 4]
# estado pai: [-5, 4] acao atual: Limpar estado_atual: [-5, 4]
# estado pai: [-5, 4] acao atual: Esquerda estado_atual: [-6, 4]
# estado pai: [-5, 4] acao atual: Direita estado_atual: [-4, 4]
# estado pai: [-5, 4] acao atual: Cima estado_atual: [-5, 3]
# estado pai: [-5, 4] acao atual: Baixo estado_atual: [-5, 5]
# estado pai: [-4, 5] acao atual: Limpar estado_atual: [-4, 5]
# estado pai: [-4, 5] acao atual: Esquerda estado_atual: [-5, 5]
# estado pai: [-4, 5] acao atual: Direita estado_atual: [-3, 5]
# estado pai: [-4, 5] acao atual: Cima estado_atual: [-4, 4]
# estado pai: [-4, 5] acao atual: Baixo estado_atual: [-4, 6]
# estado pai: [-3, 6] acao atual: Limpar estado_atual: [-3, 6]
# estado pai: [-3, 6] acao atual: Esquerda estado_atual: [-4, 6]
# estado pai: [-3, 6] acao atual: Direita estado_atual: [-2, 6]
# estado pai: [-3, 6] acao atual: Cima estado_atual: [-3, 5]
# estado pai: [-3, 6] acao atual: Baixo estado_atual: [-3, 7]
# estado pai: [-2, 7] acao atual: Limpar estado_atual: [-2, 7]
# estado pai: [-2, 7] acao atual: Esquerda estado_atual: [-3, 7]
# estado pai: [-2, 7] acao atual: Direita estado_atual: [-1, 7]
# estado pai: [-2, 7] acao atual: Cima estado_atual: [-2, 6]
# estado pai: [-2, 7] acao atual: Baixo estado_atual: [-2, 8]
# estado pai: [-1, 8] acao atual: Limpar estado_atual: [-1, 8]
# estado pai: [-1, 8] acao atual: Esquerda estado_atual: [-2, 8]
# estado pai: [-1, 8] acao atual: Direita estado_atual: [0, 8]
# estado pai: [-1, 8] acao atual: Cima estado_atual: [-1, 7]
# estado pai: [-1, 8] acao atual: Baixo estado_atual: [-1, 9]
# estado pai: [0, 9] acao atual: Limpar estado_atual: [0, 9]
# estado pai: [0, 9] acao atual: Esquerda estado_atual: [-1, 9]
# estado pai: [0, 9] acao atual: Direita estado_atual: [1, 9]
# estado pai: [0, 9] acao atual: Baixo estado_atual: [0, 10]
# estado pai: [10, 0] acao atual: Limpar estado_atual: [10, 0]
# estado pai: [10, 0] acao atual: Direita estado_atual: [11, 0]
# estado pai: [10, 0] acao atual: Cima estado_atual: [10, -1]
# estado pai: [10, 0] acao atual: Baixo estado_atual: [10, 1]
# estado pai: [9, -1] acao atual: Limpar estado_atual: [9, -1]
# estado pai: [9, -1] acao atual: Esquerda estado_atual: [8, -1]
# estado pai: [9, -1] acao atual: Direita estado_atual: [10, -1]
# estado pai: [9, -1] acao atual: Cima estado_atual: [9, -2]
# estado pai: [9, -1] acao atual: Baixo estado_atual: [9, 0]
# estado pai: [9, 1] acao atual: Limpar estado_atual: [9, 1]
# estado pai: [9, 1] acao atual: Esquerda estado_atual: [8, 1]
# estado pai: [9, 1] acao atual: Cima estado_atual: [9, 0]
# estado pai: [9, 1] acao atual: Baixo estado_atual: [9, 2]
# estado pai: [8, -2] acao atual: Limpar estado_atual: [8, -2]
# estado pai: [8, -2] acao atual: Esquerda estado_atual: [7, -2]
# estado pai: [8, -2] acao atual: Direita estado_atual: [9, -2]
# estado pai: [8, -2] acao atual: Cima estado_atual: [8, -3]
# estado pai: [8, -2] acao atual: Baixo estado_atual: [8, -1]
# estado pai: [8, 2] acao atual: Limpar estado_atual: [8, 2]
# estado pai: [8, 2] acao atual: Esquerda estado_atual: [7, 2]
# estado pai: [8, 2] acao atual: Direita estado_atual: [9, 2]
# estado pai: [8, 2] acao atual: Cima estado_atual: [8, 1]
# estado pai: [8, 2] acao atual: Baixo estado_atual: [8, 3]
# estado pai: [7, -3] acao atual: Limpar estado_atual: [7, -3]
# estado pai: [7, -3] acao atual: Esquerda estado_atual: [6, -3]
# estado pai: [7, -3] acao atual: Direita estado_atual: [8, -3]
# estado pai: [7, -3] acao atual: Cima estado_atual: [7, -4]
# estado pai: [7, -3] acao atual: Baixo estado_atual: [7, -2]
# estado pai: [7, 3] acao atual: Limpar estado_atual: [7, 3]
# estado pai: [7, 3] acao atual: Esquerda estado_atual: [6, 3]
# estado pai: [7, 3] acao atual: Direita estado_atual: [8, 3]
# estado pai: [7, 3] acao atual: Cima estado_atual: [7, 2]
# estado pai: [7, 3] acao atual: Baixo estado_atual: [7, 4]
# estado pai: [6, -4] acao atual: Limpar estado_atual: [6, -4]
# estado pai: [6, -4] acao atual: Esquerda estado_atual: [5, -4]
# estado pai: [6, -4] acao atual: Direita estado_atual: [7, -4]
# estado pai: [6, -4] acao atual: Cima estado_atual: [6, -5]
# estado pai: [6, -4] acao atual: Baixo estado_atual: [6, -3]
# estado pai: [6, 4] acao atual: Limpar estado_atual: [6, 4]
# estado pai: [6, 4] acao atual: Esquerda estado_atual: [5, 4]
# estado pai: [6, 4] acao atual: Direita estado_atual: [7, 4]
# estado pai: [6, 4] acao atual: Cima estado_atual: [6, 3]
# estado pai: [6, 4] acao atual: Baixo estado_atual: [6, 5]
# estado pai: [5, -5] acao atual: Limpar estado_atual: [5, -5]
# estado pai: [5, -5] acao atual: Esquerda estado_atual: [4, -5]
# estado pai: [5, -5] acao atual: Direita estado_atual: [6, -5]
# estado pai: [5, -5] acao atual: Cima estado_atual: [5, -6]
# ...
# estado pai: [-2, 13] acao atual: Cima estado_atual: [-2, 12]
# estado pai: [-2, 13] acao atual: Baixo estado_atual: [-2, 14]
# estado pai: [-1, 14] acao atual: Limpar estado_atual: [-1, 14]
# estado pai: [-1, 14] acao atual: Esquerda estado_atual: [-2, 14]
# estado pai: [-1, 14] acao atual: Direita estado_atual: [0, 14]
# estado pai: [-1, 14] acao atual: Cima estado_atual: [-1, 13]
# estado pai: [-1, 14] acao atual: Baixo estado_atual: [-1, 15]
# estado pai: [0, 15] acao atual: Limpar estado_atual: [0, 15]
# estado pai: [0, 15] acao atual: Esquerda estado_atual: [-1, 15]
# estado pai: [0, 15] acao atual: Direita estado_atual: [1, 15]
# estado pai: [0, 15] acao atual: Baixo estado_atual: [0, 16]
# estado pai: [16, 0] acao atual: Limpar estado_atual: [16, 0]
# estado pai: [16, 0] acao atual: Direita estado_atual: [17, 0]
# estado pai: [16, 0] acao atual: Cima estado_atual: [16, -1]
# estado pai: [16, 0] acao atual: Baixo estado_atual: [16, 1]
# estado pai: [15, -1] acao atual: Limpar estado_atual: [15, -1]
# estado pai: [15, -1] acao atual: Esquerda estado_atual: [14, -1]
# estado pai: [15, -1] acao atual: Direita estado_atual: [16, -1]
# estado pai: [15, -1] acao atual: Cima estado_atual: [15, -2]
# estado pai: [15, -1] acao atual: Baixo estado_atual: [15, 0]
# estado pai: [15, 1] acao atual: Limpar estado_atual: [15, 1]
# estado pai: [15, 1] acao atual: Esquerda estado_atual: [14, 1]
# estado pai: [15, 1] acao atual: Cima estado_atual: [15, 0]
# estado pai: [15, 1] acao atual: Baixo estado_atual: [15, 2]
# estado pai: [14, -2] acao atual: Limpar estado_atual: [14, -2]
# estado pai: [14, -2] acao atual: Esquerda estado_atual: [13, -2]
# estado pai: [14, -2] acao atual: Direita estado_atual: [15, -2]
# estado pai: [14, -2] acao atual: Cima estado_atual: [14, -3]
# estado pai: [14, -2] acao atual: Baixo estado_atual: [14, -1]
# estado pai: [14, 2] acao atual: Limpar estado_atual: [14, 2]
# estado pai: [14, 2] acao atual: Esquerda estado_atual: [13, 2]
# estado pai: [14, 2] acao atual: Direita estado_atual: [15, 2]
# estado pai: [14, 2] acao atual: Cima estado_atual: [14, 1]
# estado pai: [14, 2] acao atual: Baixo estado_atual: [14, 3]
# estado pai: [13, -3] acao atual: Limpar estado_atual: [13, -3]
# estado pai: [13, -3] acao atual: Esquerda estado_atual: [12, -3]
# estado pai: [13, -3] acao atual: Direita estado_atual: [14, -3]
# estado pai: [13, -3] acao atual: Cima estado_atual: [13, -4]
# estado pai: [13, -3] acao atual: Baixo estado_atual: [13, -2]
# estado pai: [13, 3] acao atual: Limpar estado_atual: [13, 3]
# estado pai: [13, 3] acao atual: Esquerda estado_atual: [12, 3]
# estado pai: [13, 3] acao atual: Direita estado_atual: [14, 3]
# estado pai: [13, 3] acao atual: Cima estado_atual: [13, 2]
# estado pai: [13, 3] acao atual: Baixo estado_atual: [13, 4]
# estado pai: [12, -4] acao atual: Limpar estado_atual: [12, -4]
# estado pai: [12, -4] acao atual: Esquerda estado_atual: [11, -4]
# estado pai: [12, -4] acao atual: Direita estado_atual: [13, -4]
# estado pai: [12, -4] acao atual: Cima estado_atual: [12, -5]
# estado pai: [12, -4] acao atual: Baixo estado_atual: [12, -3]
# estado pai: [12, 4] acao atual: Limpar estado_atual: [12, 4]
# estado pai: [12, 4] acao atual: Esquerda estado_atual: [11, 4]
# estado pai: [12, 4] acao atual: Direita estado_atual: [13, 4]
# estado pai: [12, 4] acao atual: Cima estado_atual: [12, 3]
# estado pai: [12, 4] acao atual: Baixo estado_atual: [12, 5]
# estado pai: [11, -5] acao atual: Limpar estado_atual: [11, -5]
# estado pai: [11, -5] acao atual: Esquerda estado_atual: [10, -5]
# estado pai: [11, -5] acao atual: Direita estado_atual: [12, -5]
# estado pai: [11, -5] acao atual: Cima estado_atual: [11, -6]
# estado pai: [11, -5] acao atual: Baixo estado_atual: [11, -4]
# estado pai: [11, 5] acao atual: Limpar estado_atual: [11, 5]
# estado pai: [11, 5] acao atual: Esquerda estado_atual: [10, 5]
# estado pai: [11, 5] acao atual: Direita estado_atual: [12, 5]
# estado pai: [11, 5] acao atual: Cima estado_atual: [11, 4]
# estado pai: [11, 5] acao atual: Baixo estado_atual: [11, 6]
# estado pai: [10, -6] acao atual: Limpar estado_atual: [10, -6]
# estado pai: [10, -6] acao atual: Esquerda estado_atual: [9, -6]
# estado pai: [10, -6] acao atual: Direita estado_atual: [11, -6]
# estado pai: [10, -6] acao atual: Cima estado_atual: [10, -7]
# estado pai: [10, -6] acao atual: Baixo estado_atual: [10, -5]
# estado pai: [10, 6] acao atual: Limpar estado_atual: [10, 6]
# estado pai: [10, 6] acao atual: Esquerda estado_atual: [9, 6]
# estado pai: [10, 6] acao atual: Direita estado_atual: [11, 6]
# estado pai: [10, 6] acao atual: Cima estado_atual: [10, 5]
# estado pai: [10, 6] acao atual: Baixo estado_atual: [10, 7]
# estado pai: [9, -7] acao atual: Limpar estado_atual: [9, -7]
# estado pai: [9, -7] acao atual: Esquerda estado_atual: [8, -7]
# estado pai: [9, -7] acao atual: Direita estado_atual: [10, -7]
# estado pai: [9, -7] acao atual: Cima estado_atual: [9, -8]
# estado pai: [9, -7] acao atual: Baixo estado_atual: [9, -6]
# estado pai: [9, 7] acao atual: Limpar estado_atual: [9, 7]
# estado pai: [9, 7] acao atual: Esquerda estado_atual: [8, 7]
# estado pai: [9, 7] acao atual: Direita estado_atual: [10, 7]
# estado pai: [9, 7] acao atual: Cima estado_atual: [9, 6]
# estado pai: [9, 7] acao atual: Baixo estado_atual: [9, 8]
# estado pai: [8, -8] acao atual: Limpar estado_atual: [8, -8]
# estado pai: [8, -8] acao atual: Esquerda estado_atual: [7, -8]
# estado pai: [8, -8] acao atual: Direita estado_atual: [9, -8]
# estado pai: [8, -8] acao atual: Cima estado_atual: [8, -9]
# estado pai: [8, -8] acao atual: Baixo estado_atual: [8, -7]
# estado pai: [8, 8] acao atual: Limpar estado_atual: [8, 8]
# estado pai: [8, 8] acao atual: Esquerda estado_atual: [7, 8]
# estado pai: [8, 8] acao atual: Direita estado_atual: [9, 8]
# estado pai: [8, 8] acao atual: Cima estado_atual: [8, 7]
# estado pai: [8, 8] acao atual: Baixo estado_atual: [8, 9]
# estado pai: [7, -9] acao atual: Limpar estado_atual: [7, -9]
# estado pai: [7, -9] acao atual: Esquerda estado_atual: [6, -9]
# estado pai: [7, -9] acao atual: Direita estado_atual: [8, -9]
# estado pai: [7, -9] acao atual: Cima estado_atual: [7, -10]
# estado pai: [7, -9] acao atual: Baixo estado_atual: [7, -8]
# estado pai: [7, 9] acao atual: Limpar estado_atual: [7, 9]
# estado pai: [7, 9] acao atual: Esquerda estado_atual: [6, 9]
# estado pai: [7, 9] acao atual: Direita estado_atual: [8, 9]
# estado pai: [7, 9] acao atual: Cima estado_atual: [7, 8]
# estado pai: [7, 9] acao atual: Baixo estado_atual: [7, 10]
# estado pai: [6, -10] acao atual: Limpar estado_atual: [6, -10]
# estado pai: [6, -10] acao atual: Esquerda estado_atual: [5, -10]
# estado pai: [6, -10] acao atual: Direita estado_atual: [7, -10]
# estado pai: [6, -10] acao atual: Cima estado_atual: [6, -11]
# estado pai: [6, -10] acao atual: Baixo estado_atual: [6, -9]
# estado pai: [6, 10] acao atual: Limpar estado_atual: [6, 10]
# estado pai: [6, 10] acao atual: Esquerda estado_atual: [5, 10]
# estado pai: [6, 10] acao atual: Direita estado_atual: [7, 10]
# estado pai: [6, 10] acao atual: Cima estado_atual: [6, 9]
# estado pai: [6, 10] acao atual: Baixo estado_atual: [6, 11]
# estado pai: [5, -11] acao atual: Limpar estado_atual: [5, -11]
# estado pai: [5, -11] acao atual: Esquerda estado_atual: [4, -11]
# estado pai: [5, -11] acao atual: Direita estado_atual: [6, -11]
# estado pai: [5, -11] acao atual: Cima estado_atual: [5, -12]
# estado pai: [5, -11] acao atual: Baixo estado_atual: [5, -10]
# estado pai: [5, 11] acao atual: Limpar estado_atual: [5, 11]
# estado pai: [5, 11] acao atual: Esquerda estado_atual: [4, 11]
# estado pai: [5, 11] acao atual: Direita estado_atual: [6, 11]
# estado pai: [5, 11] acao atual: Cima estado_atual: [5, 10]
# estado pai: [5, 11] acao atual: Baixo estado_atual: [5, 12]
# estado pai: [4, -12] acao atual: Limpar estado_atual: [4, -12]
# estado pai: [4, -12] acao atual: Esquerda estado_atual: [3, -12]
# estado pai: [4, -12] acao atual: Direita estado_atual: [5, -12]
# estado pai: [4, -12] acao atual: Cima estado_atual: [4, -13]
# estado pai: [4, -12] acao atual: Baixo estado_atual: [4, -11]
# estado pai: [4, 12] acao atual: Limpar estado_atual: [4, 12]
# estado pai: [4, 12] acao atual: Esquerda estado_atual: [3, 12]
# estado pai: [4, 12] acao atual: Direita estado_atual: [5, 12]
# estado pai: [4, 12] acao atual: Cima estado_atual: [4, 11]
# estado pai: [4, 12] acao atual: Baixo estado_atual: [4, 13]
# estado pai: [3, -13] acao atual: Limpar estado_atual: [3, -13]
# estado pai: [3, -13] acao atual: Esquerda estado_atual: [2, -13]
# estado pai: [3, -13] acao atual: Direita estado_atual: [4, -13]
# estado pai: [3, -13] acao atual: Cima estado_atual: [3, -14]
# estado pai: [3, -13] acao atual: Baixo estado_atual: [3, -12]
# estado pai: [3, 13] acao atual: Limpar estado_atual: [3, 13]
# estado pai: [3, 13] acao atual: Esquerda estado_atual: [2, 13]
# estado pai: [3, 13] acao atual: Direita estado_atual: [4, 13]
# estado pai: [3, 13] acao atual: Cima estado_atual: [3, 12]
# estado pai: [3, 13] acao atual: Baixo estado_atual: [3, 14]
# estado pai: [2, -14] acao atual: Limpar estado_atual: [2, -14]
# estado pai: [2, -14] acao atual: Esquerda estado_atual: [1, -14]
# estado pai: [2, -14] acao atual: Direita estado_atual: [3, -14]
# estado pai: [2, -14] acao atual: Cima estado_atual: [2, -15]
# estado pai: [-13, -1] acao atual: Limpar estado_atual: [-13, -1]
# estado pai: [-13, -1] acao atual: Esquerda estado_atual: [-14, -1]
# estado pai: [-13, -1] acao atual: Direita estado_atual: [-12, -1]
# estado pai: [-13, -1] acao atual: Cima estado_atual: [-13, -2]
# estado pai: [-13, -1] acao atual: Baixo estado_atual: [-13, 0]
# estado pai: [-12, -2] acao atual: Limpar estado_atual: [-12, -2]
# estado pai: [-12, -2] acao atual: Esquerda estado_atual: [-13, -2]
# estado pai: [-12, -2] acao atual: Direita estado_atual: [-11, -2]
# estado pai: [-12, -2] acao atual: Cima estado_atual: [-12, -3]
# estado pai: [-12, -2] acao atual: Baixo estado_atual: [-12, -1]
# estado pai: [-11, -3] acao atual: Limpar estado_atual: [-11, -3]
# estado pai: [-11, -3] acao atual: Esquerda estado_atual: [-12, -3]
# estado pai: [-11, -3] acao atual: Direita estado_atual: [-10, -3]
# estado pai: [-11, -3] acao atual: Cima estado_atual: [-11, -4]
# estado pai: [-11, -3] acao atual: Baixo estado_atual: [-11, -2]
# estado pai: [-10, -4] acao atual: Limpar estado_atual: [-10, -4]
# estado pai: [-10, -4] acao atual: Esquerda estado_atual: [-11, -4]
# estado pai: [-10, -4] acao atual: Direita estado_atual: [-9, -4]
# estado pai: [-10, -4] acao atual: Cima estado_atual: [-10, -5]
# estado pai: [-10, -4] acao atual: Baixo estado_atual: [-10, -3]
# estado pai: [-9, -5] acao atual: Limpar estado_atual: [-9, -5]
# estado pai: [-9, -5] acao atual: Esquerda estado_atual: [-10, -5]
# estado pai: [-9, -5] acao atual: Direita estado_atual: [-8, -5]
# estado pai: [-9, -5] acao atual: Cima estado_atual: [-9, -6]
# estado pai: [-9, -5] acao atual: Baixo estado_atual: [-9, -4]
# estado pai: [-8, -6] acao atual: Limpar estado_atual: [-8, -6]
# estado pai: [-8, -6] acao atual: Esquerda estado_atual: [-9, -6]
# estado pai: [-8, -6] acao atual: Direita estado_atual: [-7, -6]
# estado pai: [-8, -6] acao atual: Cima estado_atual: [-8, -7]
# estado pai: [-8, -6] acao atual: Baixo estado_atual: [-8, -5]
# estado pai: [-7, -7] acao atual: Limpar estado_atual: [-7, -7]
# estado pai: [-7, -7] acao atual: Esquerda estado_atual: [-8, -7]
# estado pai: [-7, -7] acao atual: Direita estado_atual: [-6, -7]
# estado pai: [-7, -7] acao atual: Cima estado_atual: [-7, -8]
# estado pai: [-7, -7] acao atual: Baixo estado_atual: [-7, -6]
# estado pai: [-6, -8] acao atual: Limpar estado_atual: [-6, -8]
# estado pai: [-6, -8] acao atual: Esquerda estado_atual: [-7, -8]
# estado pai: [-6, -8] acao atual: Direita estado_atual: [-5, -8]
# estado pai: [-6, -8] acao atual: Cima estado_atual: [-6, -9]
# estado pai: [-6, -8] acao atual: Baixo estado_atual: [-6, -7]
# estado pai: [-5, -9] acao atual: Limpar estado_atual: [-5, -9]
# estado pai: [-5, -9] acao atual: Esquerda estado_atual: [-6, -9]
# estado pai: [-5, -9] acao atual: Direita estado_atual: [-4, -9]
# estado pai: [-5, -9] acao atual: Cima estado_atual: [-5, -10]
# estado pai: [-5, -9] acao atual: Baixo estado_atual: [-5, -8]
# estado pai: [-4, -10] acao atual: Limpar estado_atual: [-4, -10]
# estado pai: [-4, -10] acao atual: Esquerda estado_atual: [-5, -10]
# estado pai: [-4, -10] acao atual: Direita estado_atual: [-3, -10]
# estado pai: [-4, -10] acao atual: Cima estado_atual: [-4, -11]
# estado pai: [-4, -10] acao atual: Baixo estado_atual: [-4, -9]
# estado pai: [-3, -11] acao atual: Limpar estado_atual: [-3, -11]
# estado pai: [-3, -11] acao atual: Esquerda estado_atual: [-4, -11]
# estado pai: [-3, -11] acao atual: Direita estado_atual: [-2, -11]
# estado pai: [-3, -11] acao atual: Cima estado_atual: [-3, -12]
# estado pai: [-3, -11] acao atual: Baixo estado_atual: [-3, -10]
# estado pai: [-2, -12] acao atual: Limpar estado_atual: [-2, -12]
# estado pai: [-2, -12] acao atual: Esquerda estado_atual: [-3, -12]
# estado pai: [-2, -12] acao atual: Direita estado_atual: [-1, -12]
# estado pai: [-2, -12] acao atual: Cima estado_atual: [-2, -13]
# estado pai: [-2, -12] acao atual: Baixo estado_atual: [-2, -11]
# estado pai: [-1, -13] acao atual: Limpar estado_atual: [-1, -13]
# estado pai: [-1, -13] acao atual: Esquerda estado_atual: [-2, -13]
# estado pai: [-1, -13] acao atual: Direita estado_atual: [0, -13]
# estado pai: [-1, -13] acao atual: Cima estado_atual: [-1, -14]
# estado pai: [-1, -13] acao atual: Baixo estado_atual: [-1, -12]
# estado pai: [0, -14] acao atual: Limpar estado_atual: [0, -14]
# estado pai: [0, -14] acao atual: Esquerda estado_atual: [-1, -14]
# estado pai: [0, -14] acao atual: Direita estado_atual: [1, -14]
# estado pai: [0, -14] acao atual: Baixo estado_atual: [0, -13]
# estado pai: [1, -15] acao atual: Limpar estado_atual: [1, -15]
# estado pai: [1, -15] acao atual: Esquerda estado_atual: [0, -15]
# estado pai: [1, -15] acao atual: Direita estado_atual: [2, -15]
# estado pai: [1, -15] acao atual: Cima estado_atual: [1, -16]
# estado pai: [1, -15] acao atual: Baixo estado_atual: [1, -14]
# estado pai: [2, 14] acao atual: Limpar estado_atual: [2, 14]
# estado pai: [2, 14] acao atual: Esquerda estado_atual: [1, 14]
# estado pai: [2, 14] acao atual: Direita estado_atual: [3, 14]
# estado pai: [2, 14] acao atual: Cima estado_atual: [2, 13]
# estado pai: [1, 15] acao atual: Limpar estado_atual: [1, 15]
# estado pai: [1, 15] acao atual: Esquerda estado_atual: [0, 15]
# estado pai: [1, 15] acao atual: Direita estado_atual: [2, 15]
# estado pai: [1, 15] acao atual: Cima estado_atual: [1, 14]
# estado pai: [1, 15] acao atual: Baixo estado_atual: [1, 16]
# estado pai: [-15, 1] acao atual: Limpar estado_atual: [-15, 1]
# estado pai: [-15, 1] acao atual: Esquerda estado_atual: [-16, 1]
# estado pai: [-15, 1] acao atual: Cima estado_atual: [-15, 0]
# estado pai: [-15, 1] acao atual: Baixo estado_atual: [-15, 2]
# estado pai: [-14, 0] acao atual: Limpar estado_atual: [-14, 0]
# estado pai: [-14, 0] acao atual: Direita estado_atual: [-13, 0]
# estado pai: [-14, 0] acao atual: Cima estado_atual: [-14, -1]
# estado pai: [-14, 0] acao atual: Baixo estado_atual: [-14, 1]
# estado pai: [-14, 2] acao atual: Limpar estado_atual: [-14, 2]
# estado pai: [-14, 2] acao atual: Esquerda estado_atual: [-15, 2]
# estado pai: [-14, 2] acao atual: Direita estado_atual: [-13, 2]
# estado pai: [-14, 2] acao atual: Cima estado_atual: [-14, 1]
# estado pai: [-14, 2] acao atual: Baixo estado_atual: [-14, 3]
# estado pai: [-13, 3] acao atual: Limpar estado_atual: [-13, 3]
# estado pai: [-13, 3] acao atual: Esquerda estado_atual: [-14, 3]
# estado pai: [-13, 3] acao atual: Direita estado_atual: [-12, 3]
# estado pai: [-13, 3] acao atual: Cima estado_atual: [-13, 2]
# estado pai: [-13, 3] acao atual: Baixo estado_atual: [-13, 4]
# Atingiu o limite em:  No{
#  Estado: [-13, 3]
#  Pai: [-13, 2],
#  Ação: Baixo,
#  Custo: 16
# }
# estado pai: [-12, 4] acao atual: Limpar estado_atual: [-12, 4]
# estado pai: [-12, 4] acao atual: Esquerda estado_atual: [-13, 4]
# estado pai: [-12, 4] acao atual: Direita estado_atual: [-11, 4]
# estado pai: [-12, 4] acao atual: Cima estado_atual: [-12, 3]
# estado pai: [-12, 4] acao atual: Baixo estado_atual: [-12, 5]

# %% [markdown]
# ## Algoritmo de Busca em Profundidade

# %%
no_inicial = None

""" Definição do Nó Raiz """

linha = 2
coluna = 2

limite = (18)

if estado(linha,coluna):
    estado_inicial = [linha-1, coluna-1]
    no_inicial = No(estado_inicial, None, None, 0, matriz_estados)

else:
    print("Erro")

# %%
def bpl_recursiva(no_atual, limite):
    
    if testar_objetivo(no_atual.matriz_transicao):
        return avaliar_solucao(no_atual)
        
    elif limite == 1:
        return "cutoff"
    
    else:
        corte = False        
        acoes = acoes_possiveis(no_atual.estado, no_atual.matriz_transicao)
        
        if acoes == [0,0,0,0,0]:
                return "erro"
        
        else:
            for i, valor in enumerate(acoes):
                acao_atual = [0,0,0,0,0]

                if valor == 1:
                    acao_atual[i] = 1
                    filho = no_filho(no_atual, acao_atual, no_atual.matriz_transicao.copy())                
                                        
                    resultado = bpl_recursiva(filho, (limite-1))

                    if resultado == "cutoff":
                        corte = True
                            
                    elif not resultado == "erro": 
                        return resultado
               
        if corte:        
            return "cutoff"
        else:
            return "erro"

# %%
# chama método recursivo para algoritmo de busca em profundidade

bpl_recursiva(no_inicial, limite)
print("\n\n", matriz_final)
